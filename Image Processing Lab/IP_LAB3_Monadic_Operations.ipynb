# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

# Load image and convert to RGB numpy array
def load_image(image_path):
    image = Image.open(image_path).convert('RGB')
    return np.array(image)

# Monadic operations on each channel
def apply_to_rgb(image_array, operation, *args):
    r, g, b = image_array[:,:,0], image_array[:,:,1], image_array[:,:,2]
    r = operation(r, *args)
    g = operation(g, *args)
    b = operation(b, *args)
    return np.stack([r, g, b], axis=2)

# Monadic operations
def add_constant(image_array, constant):
    return image_array + constant

def subtract_constant(image_array, constant):
    return image_array - constant

def negative(image_array):
    return 255 - image_array

def multiply_constant(image_array, constant):
    return image_array * constant

def divide_into_constant(image_array, constant):
    return constant / image_array

def divide_by_constant(image_array, constant):
    return image_array / constant

def and_operation(image_array, constant):
    return np.bitwise_and(image_array, constant)

def or_operation(image_array, constant):
    return np.bitwise_or(image_array, constant)

def xor_operation(image_array, constant):
    return np.bitwise_xor(image_array, constant)

# Display image using matplotlib
def display_image(image_array, title):
    plt.imshow(np.clip(image_array, 0, 255).astype(np.uint8))
    plt.title(title)
    plt.axis('off')
    plt.show()

# Example usage
if __name__ == "__main__":
    # Load image
    image_path = '/content/drive/MyDrive/CATTO.png'
    image_array = load_image(image_path)

    # Perform operations (example with constant 50)
    added_image = apply_to_rgb(image_array, add_constant, 50)
    subtracted_image = apply_to_rgb(image_array, subtract_constant, 50)
    negative_image = apply_to_rgb(image_array, negative)
    multiplied_image = apply_to_rgb(image_array, multiply_constant, 1.5)
    divided_into_image = apply_to_rgb(image_array, divide_into_constant, 2000)
    divided_by_image = apply_to_rgb(image_array, divide_by_constant, 2)
    and_image = apply_to_rgb(image_array, and_operation, 50)
    or_image = apply_to_rgb(image_array, or_operation, 50)
    xor_image = apply_to_rgb(image_array, xor_operation, 50)

    # Print and display resulting arrays and images
    operations = {
        "Added 50": added_image,
        "Subtracted 50": subtracted_image,
        "Negative": negative_image,
        "Multiplied by 1.5": multiplied_image,
        "Divided into 2000": divided_into_image,
        "Divided by 2": divided_by_image,
        "AND with 50": and_image,
        "OR with 50": or_image,
        "XOR with 50": xor_image
    }

    for title, image in operations.items():
        print(f"{title}:\n{image}\n")
        display_image(image, title)
# Out:
# Mounted at /content/drive
# <ipython-input-2-d5566a7f89f9>:34: RuntimeWarning: divide by zero encountered in divide
#   return constant / image_array
# Added 50:
# [[[116  97  90]
#   [124 106  98]
#   [138 115 109]
#   ...
#   [  5  10  14]
#   [  5  11  15]
#   [  5  10  14]]
#
#  [[120 101  93]
#   [123 104  96]
#   [141 118 111]
#   ...
#   [  5  10  15]
#   [  4   9  13]
#   [  4   9  13]]
#
#  [[126 107 100]
#   [126 108 100]
#   [137 114 108]
#   ...
#   [  5  10  14]
#   [  3   8  13]
#   [  2   8  12]]
#
#  ...
#
#  [[111  94  85]
#   [110  94  81]
#   [132 109  87]
#   ...
#   [178 144 108]
#   [185 150 112]
#   [181 144 104]]
#
#  [[110  94  84]
#   [112  96  84]
#   [122  99  84]
#   ...
#   [170 138 104]
#   [174 141 104]
#   [178 143 106]]
#
#  [[103  86  76]
#   [111  95  83]
#   [122 100  91]
#   ...
#   [167 138 107]
#   [168 138 106]
#   [165 135 101]]]
# Subtracted 50:
# [[[ 16 253 246]
#   [ 24   6 254]
#   [ 38  15   9]
#   ...
#   [161 166 170]
#   [161 167 171]
#   [161 166 170]]
#
#  [[ 20   1 249]
#   [ 23   4 252]
#   [ 41  18  11]
#   ...
#   [161 166 171]
#   [160 165 169]
#   [160 165 169]]
#
#  [[ 26   7   0]
#   [ 26   8   0]
#   [ 37  14   8]
#   ...
#   [161 166 170]
#   [159 164 169]
#   [158 164 168]]
#
#  ...
#
#  [[ 11 250 241]
#   [ 10 250 237]
#   [ 32   9 243]
#   ...
#   [ 78  44   8]
#   [ 85  50  12]
#   [ 81  44   4]]
#
#  [[ 10 250 240]
#   [ 12 252 240]
#   [ 22 255 240]
#   ...
#   [ 70  38   4]
#   [ 74  41   4]
#   [ 78  43   6]]
#
#  [[  3 242 232]
#   [ 11 251 239]
#   [ 22   0 247]
#   ...
#   [ 67  38   7]
#   [ 68  38   6]
#   [ 65  35   1]]]
# Negative:
# [[[189 208 215]
#   [181 199 207]
#   [167 190 196]
#   ...
#   [ 44  39  35]
#   [ 44  38  34]
#   [ 44  39  35]]
#
#  [[185 204 212]
#   [182 201 209]
#   [164 187 194]
#   ...
#   [ 44  39  34]
#   [ 45  40  36]
#   [ 45  40  36]]
#
#  [[179 198 205]
#   [179 197 205]
#   [168 191 197]
#   ...
#   [ 44  39  35]
#   [ 46  41  36]
#   [ 47  41  37]]
#
#  ...
#
#  [[194 211 220]
#   [195 211 224]
#   [173 196 218]
#   ...
#   [127 161 197]
#   [120 155 193]
#   [124 161 201]]
#
#  [[195 211 221]
#   [193 209 221]
#   [183 206 221]
#   ...
#   [135 167 201]
#   [131 164 201]
#   [127 162 199]]
#
#  [[202 219 229]
#   [194 210 222]
#   [183 205 214]
#   ...
#   [138 167 198]
#   [137 167 199]
#   [140 170 204]]]
# Multiplied by 1.5:
# [[[ 99.   70.5  60. ]
#   [111.   84.   72. ]
#   [132.   97.5  88.5]
#   ...
#   [316.5 324.  330. ]
#   [316.5 325.5 331.5]
#   [316.5 324.  330. ]]
#
#  [[105.   76.5  64.5]
#   [109.5  81.   69. ]
#   [136.5 102.   91.5]
#   ...
#   [316.5 324.  331.5]
#   [315.  322.5 328.5]
#   [315.  322.5 328.5]]
#
#  [[114.   85.5  75. ]
#   [114.   87.   75. ]
#   [130.5  96.   87. ]
#   ...
#   [316.5 324.  330. ]
#   [313.5 321.  328.5]
#   [312.  321.  327. ]]
#
#  ...
#
#  [[ 91.5  66.   52.5]
#   [ 90.   66.   46.5]
#   [123.   88.5  55.5]
#   ...
#   [192.  141.   87. ]
#   [202.5 150.   93. ]
#   [196.5 141.   81. ]]
#
#  [[ 90.   66.   51. ]
#   [ 93.   69.   51. ]
#   [108.   73.5  51. ]
#   ...
#   [180.  132.   81. ]
#   [186.  136.5  81. ]
#   [192.  139.5  84. ]]
#
#  [[ 79.5  54.   39. ]
#   [ 91.5  67.5  49.5]
#   [108.   75.   61.5]
#   ...
#   [175.5 132.   85.5]
#   [177.  132.   84. ]
#   [172.5 127.5  76.5]]]
# Divided into 2000:
# [[[30.3030303  42.55319149 50.        ]
#   [27.02702703 35.71428571 41.66666667]
#   [22.72727273 30.76923077 33.89830508]
#   ...
#   [ 9.47867299  9.25925926  9.09090909]
#   [ 9.47867299  9.21658986  9.04977376]
#   [ 9.47867299  9.25925926  9.09090909]]
#
#  [[28.57142857 39.21568627 46.51162791]
#   [27.39726027 37.03703704 43.47826087]
#   [21.97802198 29.41176471 32.78688525]
#   ...
#   [ 9.47867299  9.25925926  9.04977376]
#   [ 9.52380952  9.30232558  9.13242009]
#   [ 9.52380952  9.30232558  9.13242009]]
#
#  [[26.31578947 35.0877193  40.        ]
#   [26.31578947 34.48275862 40.        ]
#   [22.98850575 31.25       34.48275862]
#   ...
#   [ 9.47867299  9.25925926  9.09090909]
#   [ 9.56937799  9.34579439  9.13242009]
#   [ 9.61538462  9.34579439  9.17431193]]
#
#  ...
#
#  [[32.78688525 45.45454545 57.14285714]
#   [33.33333333 45.45454545 64.51612903]
#   [24.3902439  33.89830508 54.05405405]
#   ...
#   [15.625      21.27659574 34.48275862]
#   [14.81481481 20.         32.25806452]
#   [15.26717557 21.27659574 37.03703704]]
#
#  [[33.33333333 45.45454545 58.82352941]
#   [32.25806452 43.47826087 58.82352941]
#   [27.77777778 40.81632653 58.82352941]
#   ...
#   [16.66666667 22.72727273 37.03703704]
#   [16.12903226 21.97802198 37.03703704]
#   [15.625      21.50537634 35.71428571]]
#
#  [[37.73584906 55.55555556 76.92307692]
#   [32.78688525 44.44444444 60.60606061]
#   [27.77777778 40.         48.7804878 ]
#   ...
#   [17.09401709 22.72727273 35.0877193 ]
#   [16.94915254 22.72727273 35.71428571]
#   [17.39130435 23.52941176 39.21568627]]]
# Divided by 2:
# [[[ 33.   23.5  20. ]
#   [ 37.   28.   24. ]
#   [ 44.   32.5  29.5]
#   ...
#   [105.5 108.  110. ]
#   [105.5 108.5 110.5]
#   [105.5 108.  110. ]]
#
#  [[ 35.   25.5  21.5]
#   [ 36.5  27.   23. ]
#   [ 45.5  34.   30.5]
#   ...
#   [105.5 108.  110.5]
#   [105.  107.5 109.5]
#   [105.  107.5 109.5]]
#
#  [[ 38.   28.5  25. ]
#   [ 38.   29.   25. ]
#   [ 43.5  32.   29. ]
#   ...
#   [105.5 108.  110. ]
#   [104.5 107.  109.5]
#   [104.  107.  109. ]]
#
#  ...
#
#  [[ 30.5  22.   17.5]
#   [ 30.   22.   15.5]
#   [ 41.   29.5  18.5]
#   ...
#   [ 64.   47.   29. ]
#   [ 67.5  50.   31. ]
#   [ 65.5  47.   27. ]]
#
#  [[ 30.   22.   17. ]
#   [ 31.   23.   17. ]
#   [ 36.   24.5  17. ]
#   ...
#   [ 60.   44.   27. ]
#   [ 62.   45.5  27. ]
#   [ 64.   46.5  28. ]]
#
#  [[ 26.5  18.   13. ]
#   [ 30.5  22.5  16.5]
#   [ 36.   25.   20.5]
#   ...
#   [ 58.5  44.   28.5]
#   [ 59.   44.   28. ]
#   [ 57.5  42.5  25.5]]]
# AND with 50:
# [[[ 2 34 32]
#   [ 2 48 48]
#   [16  0 50]
#   ...
#   [18 16 16]
#   [18 16 16]
#   [18 16 16]]
#
#  [[ 2 50 34]
#   [ 0 50 34]
#   [18  0 48]
#   ...
#   [18 16 16]
#   [18 18 18]
#   [18 18 18]]
#
#  [[ 0 48 50]
#   [ 0 50 50]
#   [18  0 50]
#   ...
#   [18 16 16]
#   [16 18 18]
#   [16 18 18]]
#
#  ...
#
#  [[48 32 34]
#   [48 32 18]
#   [18 50 32]
#   ...
#   [ 0 18 50]
#   [ 2 32 50]
#   [ 2 18 50]]
#
#  [[48 32 34]
#   [50 34 34]
#   [ 0 48 34]
#   ...
#   [48 16 50]
#   [48 18 50]
#   [ 0 16 48]]
#
#  [[48 32 18]
#   [48 32 32]
#   [ 0 50 32]
#   ...
#   [48 16 48]
#   [50 16 48]
#   [50 16 50]]]
# OR with 50:
# [[[114  63  58]
#   [122  58  50]
#   [122 115  59]
#   ...
#   [243 250 254]
#   [243 251 255]
#   [243 250 254]]
#
#  [[118  51  59]
#   [123  54  62]
#   [123 118  63]
#   ...
#   [243 250 255]
#   [242 247 251]
#   [242 247 251]]
#
#  [[126  59  50]
#   [126  58  50]
#   [119 114  58]
#   ...
#   [243 250 254]
#   [243 246 251]
#   [242 246 250]]
#
#  ...
#
#  [[ 63  62  51]
#   [ 62  62  63]
#   [114  59  55]
#   ...
#   [178 126  58]
#   [183 118  62]
#   [179 126  54]]
#
#  [[ 62  62  50]
#   [ 62  62  50]
#   [122  51  50]
#   ...
#   [122 122  54]
#   [126 123  54]
#   [178 127  58]]
#
#  [[ 55  54  58]
#   [ 63  63  51]
#   [122  50  59]
#   ...
#   [119 122  59]
#   [118 122  58]
#   [115 119  51]]]
# XOR with 50:
# [[[112  29  26]
#   [120  10   2]
#   [106 115   9]
#   ...
#   [225 234 238]
#   [225 235 239]
#   [225 234 238]]
#
#  [[116   1  25]
#   [123   4  28]
#   [105 118  15]
#   ...
#   [225 234 239]
#   [224 229 233]
#   [224 229 233]]
#
#  [[126  11   0]
#   [126   8   0]
#   [101 114   8]
#   ...
#   [225 234 238]
#   [227 228 233]
#   [226 228 232]]
#
#  ...
#
#  [[ 15  30  17]
#   [ 14  30  45]
#   [ 96   9  23]
#   ...
#   [178 108   8]
#   [181  86  12]
#   [177 108   4]]
#
#  [[ 14  30  16]
#   [ 12  28  16]
#   [122   3  16]
#   ...
#   [ 74 106   4]
#   [ 78 105   4]
#   [178 111  10]]
#
#  [[  7  22  40]
#   [ 15  31  19]
#   [122   0  27]
#   ...
#   [ 71 106  11]
#   [ 68 106  10]
#   [ 65 103   1]]]
